# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import numpy as np
from scipy.stats import ttest_ind

import extra_scripts.create_vectors as cv
import extra_scripts.utils as utils
from word_task.non_neural.predict import getXy

# %%
train_items = cv.load_prediction_items("../data/cmv_triples_train_token.jsonlist.gz")
# Out:
# 2019-09-19 07:37:11,582 - Loading ../data/cmv_triples_train_token.jsonlist.gz.
# 100%|██████████| 26329/26329 [00:34<00:00, 757.48it/s]
# 2019-09-19 07:37:50,361 - Loading ../data/cmv_triples_train_token.jsonlist.gz.npy.
# 2019-09-19 07:38:42,603 - Splitting vectors into instances.
# 100%|██████████| 26329/26329 [00:08<00:00, 2965.76it/s]
# 2019-09-19 07:38:52,339 - Extracting unique stems.
# 100%|██████████| 26329/26329 [01:50<00:00, 238.61it/s]

# %%
def split_by_stop(items):
    items_stop = [item for item in items if utils.is_stop(item[0])]
    items_stopless = [item for item in items if not utils.is_stop(item[0])]
    return items, items_stop, items_stopless

# %%
train_all, train_stop, train_stopless = split_by_stop(train_items)
print(len(train_all), len(train_stop), len(train_stopless))

X_train_all, y_train_all = getXy(train_all)
print(X_train_all.shape, y_train_all.shape)

X_train_stop, y_train_stop = getXy(train_stop)
print(X_train_stop.shape, y_train_stop.shape)

X_train_stopless, y_train_stopless = getXy(train_stopless)
print(X_train_stopless.shape, y_train_stopless.shape)
# Out:
# 5900801 1553843 4346958
# (5900801, 66) (5900801,)
# (1553843, 66) (1553843,)
# (4346958, 66) (4346958,)

# %%
def ttest(X, y):
    y_not = np.logical_not(y)

    for feat_idx, feat in enumerate(cv.FEATURE_LABELS[:-1]):
        feature_vals = X[:, feat_idx]
    
        features_when_true = feature_vals[y]
        features_when_false = feature_vals[y_not]

        tstat, pval = ttest_ind(features_when_true, features_when_false, equal_var=False)
        print("{:17} pval: {:.10f} tstat: {:3.3f}".format(feat, round(pval, 10), round(tstat, 10)))

print("ALL STEMS")
ttest(X_train_all, y_train_all)
print("\nJUST STOPWORDS")
ttest(X_train_stop, y_train_stop)
print("\nJUST NONSTOPWORDS")
ttest(X_train_stopless, y_train_stopless)
# Out:
# ALL STEMS
# OP_PC_LEN_DIFF    pval: 0.0000000000 tstat: -79.745
# AVG_TOK_LEN_DIFF  pval: 0.0000000000 tstat: -36.176
# OP_LEN            pval: 0.0000000000 tstat: -40.744
# PC_LEN            pval: 0.0000000000 tstat: 47.550
# OP_PC_POS_DIFF    pval: 0.0000000000 tstat: -72.749
# DEPTH             pval: 0.0000000000 tstat: 29.572
# IDF               pval: 0.0000000000 tstat: -797.627
# STEM_CHARS        pval: 0.0000000000 tstat: -526.671
# WORDNET_DEPTH_MIN pval: 0.0000000000 tstat: -22.706
# WORDNET_DEPTH_MAX pval: 0.0000000000 tstat: -27.576
# TRANSFER_PROB     pval: 0.0000000000 tstat: 757.474
# OP_ADP            pval: 0.0000000000 tstat: 202.793
# OP_PRON           pval: 0.0000000000 tstat: 177.726
# OP_X              pval: 0.0000000000 tstat: -111.535
# OP_DET            pval: 0.0000000000 tstat: 205.502
# OP_ADJ            pval: 0.0000000000 tstat: -240.681
# OP_PROPN          pval: 0.0000000000 tstat: -125.960
# OP_VERB           pval: 0.0000000000 tstat: -35.238
# OP_PART           pval: 0.0000000000 tstat: 73.063
# OP_CCONJ          pval: 0.0000000000 tstat: 112.876
# OP_INTJ           pval: 0.0000000000 tstat: -104.524
# OP_NOUN           pval: 0.0000000000 tstat: -245.848
# OP_NUM            pval: 0.0000000000 tstat: -120.596
# OP_ADV            pval: 0.0000000000 tstat: -25.725
# OP_PUNCT          pval: 0.0000000000 tstat: -116.182
# OP_SYM            pval: 0.0000000000 tstat: -114.282
# OP_AUX            pval: 0.0000000000 tstat: -68.895
# PC_ADP            pval: 0.0000000000 tstat: 171.164
# PC_PRON           pval: 0.0000000000 tstat: 132.268
# PC_X              pval: 0.0000000000 tstat: -422.972
# PC_DET            pval: 0.0000000000 tstat: 169.197
# PC_ADJ            pval: 0.0000000000 tstat: -114.342
# PC_PROPN          pval: 0.0000000000 tstat: -148.029
# PC_VERB           pval: 0.0000000000 tstat: 59.273
# PC_PART           pval: 0.0000000000 tstat: -19.788
# PC_CCONJ          pval: 0.0000000000 tstat: 40.961
# PC_INTJ           pval: 0.0000000000 tstat: -330.234
# PC_NOUN           pval: 0.0000000000 tstat: -55.234
# PC_NUM            pval: 0.0000000000 tstat: -226.427
# PC_ADV            pval: 0.3868040285 tstat: 0.865
# PC_PUNCT          pval: 0.0000000000 tstat: -384.771
# PC_SYM            pval: 0.0000000000 tstat: -502.040
# PC_AUX            pval: 0.0000000000 tstat: -281.588
# OP_SUBJ           pval: 0.0000000000 tstat: 92.920
# OP_OBJ            pval: 0.0000000000 tstat: -149.202
# OP_OTHER          pval: 0.0000000000 tstat: 19.777
# PC_SUBJ           pval: 0.0000000000 tstat: -84.307
# PC_OBJ            pval: 0.0000000000 tstat: -316.646
# PC_OTHER          pval: 0.0000000000 tstat: 250.159
# OP_IS_ENT         pval: 0.0000000000 tstat: 18.693
# PC_IS_ENT         pval: 0.0000000000 tstat: 32.984
# OP_TF             pval: 0.0000000000 tstat: 435.032
# OP_NORM_TF        pval: 0.0000000000 tstat: 346.704
# PC_TF             pval: 0.0000000000 tstat: 591.752
# PC_NORM_TF        pval: 0.0000000000 tstat: 368.884
# OP_SFS            pval: 0.0000000000 tstat: 194.644
# PC_SFS            pval: 0.0000000000 tstat: 492.816
# OP_LOC            pval: 0.0000000000 tstat: 18.409
# PC_LOC            pval: 0.0002234519 tstat: 3.691
# OP_QUOTE          pval: 0.0000000000 tstat: 83.705
# PC_QUOTE          pval: 0.0000000000 tstat: 152.958
# OCCURS_IN_OP_PC   pval: 0.0000000000 tstat: 587.292
# STEM_POS_DIFF     pval: 0.0000000000 tstat: -570.497
# STEM_DEP_DIFF     pval: 0.0000000000 tstat: -477.512
# SFS_IN_OP_NOT_PC  pval: 0.0000000000 tstat: -282.472
# SFS_IN_PC_NOT_OP  pval: 0.0000000000 tstat: 27.694
#
# JUST STOPWORDS
# OP_PC_LEN_DIFF    pval: 0.0000000000 tstat: 7.334
# AVG_TOK_LEN_DIFF  pval: 0.0000000000 tstat: -32.369
# OP_LEN            pval: 0.0000000000 tstat: 36.564
# PC_LEN            pval: 0.0000000000 tstat: 71.767
# OP_PC_POS_DIFF    pval: 0.0000000000 tstat: -57.718
# DEPTH             pval: 0.0000000000 tstat: 12.789
# IDF               pval: 0.0000000000 tstat: -543.994
# STEM_CHARS        pval: 0.0000000000 tstat: -283.038
# WORDNET_DEPTH_MIN pval: 0.0000000000 tstat: 26.358
# WORDNET_DEPTH_MAX pval: 0.0000000000 tstat: 28.905
# TRANSFER_PROB     pval: 0.0000000000 tstat: 554.649
# OP_ADP            pval: 0.0000000000 tstat: 36.211
# OP_PRON           pval: 0.0000000000 tstat: 67.790
# OP_X              pval: 0.0000000000 tstat: -140.814
# OP_DET            pval: 0.0000000000 tstat: 69.410
# OP_ADJ            pval: 0.0000000000 tstat: -118.886
# OP_PROPN          pval: 0.0000000000 tstat: -126.205
# OP_VERB           pval: 0.0000000000 tstat: 8.285
# OP_PART           pval: 0.0000000000 tstat: 18.002
# OP_CCONJ          pval: 0.0000000000 tstat: 54.555
# OP_INTJ           pval: 0.0000000000 tstat: -128.182
# OP_NOUN           pval: 0.0000000000 tstat: -91.009
# OP_NUM            pval: 0.0000000000 tstat: -141.111
# OP_ADV            pval: 0.0000000000 tstat: -114.614
# OP_PUNCT          pval: 0.0000000000 tstat: -138.719
# OP_SYM            pval: 0.0000000000 tstat: -141.223
# OP_AUX            pval: 0.0000000000 tstat: -94.256
# PC_ADP            pval: 0.0000000000 tstat: 61.365
# PC_PRON           pval: 0.0000000000 tstat: 77.565
# PC_X              pval: 0.0000000000 tstat: -261.708
# PC_DET            pval: 0.0000000000 tstat: 91.187
# PC_ADJ            pval: 0.0000000000 tstat: -111.954
# PC_PROPN          pval: 0.0000000000 tstat: -235.480
# PC_VERB           pval: 0.0000000000 tstat: 32.814
# PC_PART           pval: 0.0000000000 tstat: 8.625
# PC_CCONJ          pval: 0.0000000000 tstat: 41.320
# PC_INTJ           pval: 0.0000000000 tstat: -220.566
# PC_NOUN           pval: 0.0000000000 tstat: -163.524
# PC_NUM            pval: 0.0000000000 tstat: -261.584
# PC_ADV            pval: 0.0000000000 tstat: -82.622
# PC_PUNCT          pval: 0.0000000000 tstat: -259.293
# PC_SYM            pval: 0.0000000000 tstat: -262.937
# PC_AUX            pval: 0.0000000000 tstat: -189.783
# OP_SUBJ           pval: 0.0000000000 tstat: 36.455
# OP_OBJ            pval: 0.0000000000 tstat: -112.446
# OP_OTHER          pval: 0.0000000000 tstat: 22.638
# PC_SUBJ           pval: 0.0000000000 tstat: -15.873
# PC_OBJ            pval: 0.0000000000 tstat: -211.718
# PC_OTHER          pval: 0.0000000000 tstat: 113.741
# OP_IS_ENT         pval: 0.0000000000 tstat: 41.378
# PC_IS_ENT         pval: 0.0000000000 tstat: 28.449
# OP_TF             pval: 0.0000000000 tstat: 346.615
# OP_NORM_TF        pval: 0.0000000000 tstat: 233.841
# PC_TF             pval: 0.0000000000 tstat: 366.737
# PC_NORM_TF        pval: 0.0000000000 tstat: 207.023
# OP_SFS            pval: 0.0000000000 tstat: 182.539
# PC_SFS            pval: 0.0000000000 tstat: 275.649
# OP_LOC            pval: 0.4915006680 tstat: -0.688
# PC_LOC            pval: 0.0000000000 tstat: -8.265
# OP_QUOTE          pval: 0.0000000000 tstat: 60.350
# PC_QUOTE          pval: 0.0000000000 tstat: 110.038
# OCCURS_IN_OP_PC   pval: 0.0000000000 tstat: 360.293
# STEM_POS_DIFF     pval: 0.0000000000 tstat: -354.899
# STEM_DEP_DIFF     pval: 0.0000000000 tstat: -313.146
# SFS_IN_OP_NOT_PC  pval: 0.0000000000 tstat: -153.998
# SFS_IN_PC_NOT_OP  pval: 0.0000000000 tstat: -45.260
#
# JUST NONSTOPWORDS
# OP_PC_LEN_DIFF    pval: 0.0000000000 tstat: -41.360
# AVG_TOK_LEN_DIFF  pval: 0.0000000000 tstat: -37.830
# OP_LEN            pval: 0.0000000000 tstat: -7.105
# PC_LEN            pval: 0.0000000000 tstat: 70.282
# OP_PC_POS_DIFF    pval: 0.0000000000 tstat: -84.756
# DEPTH             pval: 0.0000000000 tstat: 23.103
# IDF               pval: 0.0000000000 tstat: -295.864
# STEM_CHARS        pval: 0.0000000000 tstat: -102.978
# WORDNET_DEPTH_MIN pval: 0.0000000000 tstat: 18.257
# WORDNET_DEPTH_MAX pval: 0.0000000000 tstat: 15.292
# TRANSFER_PROB     pval: 0.0000000000 tstat: 333.763
# OP_ADP            pval: 0.0000000000 tstat: 26.707
# OP_PRON           pval: 0.0000000000 tstat: 51.865
# OP_X              pval: 0.0000000000 tstat: 40.817
# OP_DET            pval: 0.0000000000 tstat: 26.742
# OP_ADJ            pval: 0.0000000000 tstat: -81.078
# OP_PROPN          pval: 0.0000000000 tstat: -7.471
# OP_VERB           pval: 0.0000246149 tstat: -4.218
# OP_PART           pval: 0.0000000000 tstat: 62.277
# OP_CCONJ          pval: 0.0000000000 tstat: 47.756
# OP_INTJ           pval: 0.0000000000 tstat: 31.481
# OP_NOUN           pval: 0.0000000000 tstat: -9.231
# OP_NUM            pval: 0.0000764463 tstat: -3.955
# OP_ADV            pval: 0.0000000000 tstat: 26.991
# OP_PUNCT          pval: 0.0000000000 tstat: 36.392
# OP_SYM            pval: 0.0000000000 tstat: 70.540
# OP_AUX            pval: 0.0000000000 tstat: 45.750
# PC_ADP            pval: 0.0000000000 tstat: -65.221
# PC_PRON           pval: 0.0000000000 tstat: -215.293
# PC_X              pval: 0.0000000000 tstat: -234.451
# PC_DET            pval: 0.0000000000 tstat: -166.622
# PC_ADJ            pval: 0.0000000000 tstat: 16.598
# PC_PROPN          pval: 0.0000000000 tstat: -27.208
# PC_VERB           pval: 0.0000000000 tstat: 82.535
# PC_PART           pval: 0.0000000000 tstat: -286.413
# PC_CCONJ          pval: 0.0000000000 tstat: -251.703
# PC_INTJ           pval: 0.0000000000 tstat: -167.884
# PC_NOUN           pval: 0.0000000000 tstat: 136.509
# PC_NUM            pval: 0.0000000000 tstat: -87.216
# PC_ADV            pval: 0.0000000000 tstat: 38.536
# PC_PUNCT          pval: 0.0000000000 tstat: -197.720
# PC_SYM            pval: 0.0000000000 tstat: -315.060
# PC_AUX            pval: 0.0000000000 tstat: -138.901
# OP_SUBJ           pval: 0.0000000000 tstat: 90.624
# OP_OBJ            pval: 0.0000000000 tstat: 42.047
# OP_OTHER          pval: 0.0000000000 tstat: -84.502
# PC_SUBJ           pval: 0.0000000000 tstat: -122.810
# PC_OBJ            pval: 0.0000000000 tstat: -109.168
# PC_OTHER          pval: 0.0000000000 tstat: 154.218
# OP_IS_ENT         pval: 0.0000000000 tstat: 31.638
# PC_IS_ENT         pval: 0.0000000000 tstat: 41.138
# OP_TF             pval: 0.0000000000 tstat: 92.941
# OP_NORM_TF        pval: 0.0000000000 tstat: 66.802
# PC_TF             pval: 0.0000000000 tstat: 338.458
# PC_NORM_TF        pval: 0.0000000000 tstat: 192.821
# OP_SFS            pval: 0.0000000000 tstat: 13.613
# PC_SFS            pval: 0.0000000000 tstat: 307.534
# OP_LOC            pval: 0.0000000000 tstat: 23.329
# PC_LOC            pval: 0.0000000000 tstat: 16.847
# OP_QUOTE          pval: 0.0000000000 tstat: 32.843
# PC_QUOTE          pval: 0.0000000000 tstat: 74.016
# OCCURS_IN_OP_PC   pval: 0.0000000000 tstat: 262.751
# STEM_POS_DIFF     pval: 0.0000000000 tstat: -245.630
# STEM_DEP_DIFF     pval: 0.0000000000 tstat: -172.919
# SFS_IN_OP_NOT_PC  pval: 0.0000000000 tstat: -159.833
# SFS_IN_PC_NOT_OP  pval: 0.0000000000 tstat: 147.330
